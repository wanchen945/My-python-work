# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([ 1.1099821 ,  0.98562608,  3.11670306, -0.02310912, -0.71298492,
#         0.14708579,  0.28400743, -0.82529323, -0.45715801,  0.80210011])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
sin(1/2)
# Out:
# 0.479425538604203

# %%
sin(1)
# Out:
# 0.8414709848078965

# %%
sin(2)
# Out:
# 0.9092974268256817

# %%
plot([4,8,5,2,3,6,7,])
